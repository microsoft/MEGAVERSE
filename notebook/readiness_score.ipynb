# %%
from collections import defaultdict as dd

lang_class = {0:[],1:[],2:[],3:[],4:[],5:[],6:[]}#6 is code mix -- may be we can add this to respective 2nd lang grp
class_lang = dd(list)
f=open("dataset/lang_class_mapping.csv");L=f.readlines();f.close()
#lang-name, code, class
for ele in L:
    ele = ele.strip("\n").strip().split("\t")
    if len(ele)>2:
        lang_class[int(ele[2].strip())].append((ele[0].strip(),ele[1].strip()))
        class_lang[ele[0].strip()].append(ele[2].strip())
    else:
        print(ele)
        
print("<Language Class Stats>")
for i in range(7):
    print(i,len(lang_class[i]))
# Out:
# ['Assamese', 'as']
# ['Czech', 'cs']
# ['Danish', 'da']
# ['Kashmiri', 'ka']
# ['Norwegian', 'no']
# ['Swedish', 'sv']
# <Language Class Stats>
# 0 8
# 1 18
# 2 8
# 3 18
# 4 14
# 5 10
# 6 2

# %%
track_dataset = dd(list)
dataset_track = dd(list)
f=open("dataset/track_dataset_mapping.csv");L=f.readlines();f.close()
for ele in L[1:]:
    ele = ele.strip("\n").split("\t")
    if ele[1]:
        track_dataset[ele[0]] = [e.strip() for e in ele[1].split(",")]
        for data in ele[1].split(","):
            dataset_track[data.strip()] = ele[0]
    else:
        print(ele[0]," has no dataset")
print(track_dataset, len(track_dataset))
print(dataset_track, len(dataset_track))
# Out:
# Computational Social Science and Cultural Analytics  has no dataset
# Discourse and Pragmatics  has no dataset
# Information Retrieval and Text Mining  has no dataset
# Interpretability and Analysis of Models for NLP  has no dataset
# Linguistic Theories, Cognitive Modeling, and Psycholinguistics  has no dataset
# Machine Learning for NLP  has no dataset
# Phonology, Morphology, and Word Segmentation  has no dataset
# Resources and Evaluation  has no dataset
# Semantics: Lexical  has no dataset
# Speech and Multimodality  has no dataset
# defaultdict(<class 'list'>, {'Dialogue and Interactive Systems': ['X-RiSAWOZ'], 'Ethics and NLP': ['Jigsaw', 'WinoMT'], 'Generation': ['PAN-X'], 'Language Grounding to Vision, Robotics and Beyond': ['MARVL', 'XM3600'], 'Machine Translation and Multilinguality': ['IN22'], 'NLP Applications': ['XstoryCloze', 'XCOPA'], 'Question Answering': ['Belebele', 'AfriQA', 'IndicQA', 'TyDiQA-GoldP', 'MLQA', 'XQuAD'], 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': ['XNLI', 'IndicXNLI', 'GLUECoS-NLI', 'PAWS-X'], 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': ['GLUECoS-SA', 'En-Es-CS'], 'Summarization': ['XLSum'], 'Syntax:Tagging,Chunking and Parsing': ['UDPOS']}) 11
# defaultdict(<class 'list'>, {'X-RiSAWOZ': 'Dialogue and Interactive Systems', 'Jigsaw': 'Ethics and NLP', 'WinoMT': 'Ethics and NLP', 'PAN-X': 'Generation', 'MARVL': 'Language Grounding to Vision, Robotics and Beyond', 'XM3600': 'Language Grounding to Vision, Robotics and Beyond', 'IN22': 'Machine Translation and Multilinguality', 'XstoryCloze': 'NLP Applications', 'XCOPA': 'NLP Applications', 'Belebele': 'Question Answering', 'AfriQA': 'Question Answering', 'IndicQA': 'Question Answering', 'TyDiQA-GoldP': 'Question Answering', 'MLQA': 'Question Answering', 'XQuAD': 'Question Answering', 'XNLI': 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas', 'IndicXNLI': 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas', 'GLUECoS-NLI': 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas', 'PAWS-X': 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas', 'GLUECoS-SA': 'Sentiment Analysis, Stylistic Analysis,and Argument Mining', 'En-Es-CS': 'Sentiment Analysis, Stylistic Analysis,and Argument Mining', 'XLSum': 'Summarization', 'UDPOS': 'Syntax:Tagging,Chunking and Parsing'}) 23

# %%
'''
print(track_dataset, len(track_dataset))
print(dataset_track, len(dataset_track))
lang_class 
class_lang 
'''
from collections import defaultdict as dd

all_data = {0:dd(),1:dd(),2:dd(),3:dd(),4:dd(),5:dd(),6:dd()}
for class_id in all_data.keys():
    for lang in lang_class[class_id]:
        lang=lang[0]
        all_data[class_id][lang]=dd()
        for track in track_dataset:
            all_data[class_id][lang][track]=dd()
            for dataset in track_dataset[track]:
                all_data[class_id][lang][track][dataset] = 0.0
        print(class_id, lang, all_data[class_id][lang])    
        
#print(all_data)
# Out:
# 0 Bemba defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Fon defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Haitian Creole defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Kinyarwanda defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Pidgin defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Sinhala defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Twi defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 0 Zulu defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Azerbaijani defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Welsh defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Scottish_gaelic defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Gujarati defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Igbo defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Javanese defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Kannada defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Kyrgyz defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Malayalam defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Burmese defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Nepali defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Oromo defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Oriya defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Pashto defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Quechua defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Kirundi defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Somali defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 1 Telugu defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Amharic defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Hausa defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Marathi defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Punjabi defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Swahili defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Tigrinya defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Wolof defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 2 Yoruba defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Afrikaans defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Bulgarian defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Bengali defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Greek defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Estonian defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Hebrew defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Indonesian defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Georgian defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Kazakh defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Lithuanian defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Malay defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 3 Romanian defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# ...
# 4 Serbian_Latin defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 4 Turkish defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 4 Vietnamese defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Arabic defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 German defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 English defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Spanish defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Finnish defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 French defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Japanese defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Chinese defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Chinese_Simplified defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 5 Chinese_Traditional defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 6 English-Hindi defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})
# 6 English-Spanish defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {'X-RiSAWOZ': 0.0}), 'Ethics and NLP': defaultdict(None, {'Jigsaw': 0.0, 'WinoMT': 0.0}), 'Generation': defaultdict(None, {'PAN-X': 0.0}), 'Language Grounding to Vision, Robotics and Beyond': defaultdict(None, {'MARVL': 0.0, 'XM3600': 0.0}), 'Machine Translation and Multilinguality': defaultdict(None, {'IN22': 0.0}), 'NLP Applications': defaultdict(None, {'XstoryCloze': 0.0, 'XCOPA': 0.0}), 'Question Answering': defaultdict(None, {'Belebele': 0.0, 'AfriQA': 0.0, 'IndicQA': 0.0, 'TyDiQA-GoldP': 0.0, 'MLQA': 0.0, 'XQuAD': 0.0}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {'XNLI': 0.0, 'IndicXNLI': 0.0, 'GLUECoS-NLI': 0.0, 'PAWS-X': 0.0}), 'Sentiment Analysis, Stylistic Analysis,and Argument Mining': defaultdict(None, {'GLUECoS-SA': 0.0, 'En-Es-CS': 0.0}), 'Summarization': defaultdict(None, {'XLSum': 0.0}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {'UDPOS': 0.0})})

# %%
f=open("dataset/genmodel_score.csv", encoding='windows-1254');L=f.readlines();f.close()
#print(L[0].split(","))
L_header = L[0].split(",")
model_scores = dd(list)
x=[]
model_to_eval = "GPT-3.5-Turbo Zero-Shot Cross Lingual"
for ele in L[1:]:
    i=0
    #model_scores[Language-Class][Task][Dataset][][Score]
    #model_scores[L_header[5]][][L_header[0]][model_to_eval][]
    ele = ele.split(",")
    class_id = class_lang[ele[2].strip()]
    lang = ele[2].strip()
    track = dataset_track[ele[0]].strip()
    dataset = ele[0].strip()
    print(ele[10],class_id,lang,track,dataset,class_lang)
    if lang in ['Assamese','Czech','Danish', 'Kashmiri','Norwegian', 'Swedish']:
        continue
    all_data[int(class_id[0])][lang][track][dataset] = ele[10]
    

'''
L[0] #Dataset
L[2] #Language
L[4] #Language Code
L[5] #Language Class
L[10]#'GPT-3.5-Turbo Monolingual', 
L[11]#'GPT-3.5-Turbo Translate-Test', 
L[12]#'GPT-3.5-Turbo Zero-Shot Cross Lingual', 
L[13]#'GPT-4 Monolingual', 
L[14]#'GPT-4 Translate-Test', 
L[15]#'GPT-4 Zero-Shot Cross Lingual', 
L[16]#'TULRv6', 
L[17]#'BLOOMZ', 
L[18]#'XLM-R', 
L[19]#'mBERT', 
L[20]#'MuRIL', 
L[21]#'XGLM', 
L[22]#'mT5', 
L[23]#'PaLM2 Zero-Shot', 
L[24]#'PaLM2 Monolingual', 
L[25]#'Llama2-7B Monolingual', 
L[26]#'Llama2-13B Monolingual', 
L[27]#'Llama2-70B Monolingual', 
L[28]#'LLaVa-1.5-13B Monolingual', 
L[29]#'LLaVa-1.5-13B Translate-Test'
'''
# Out:
# 0.044 ['0'] Bemba Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.105 ['0'] Fon Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.112 ['2'] Hausa Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.205 ['1'] Igbo Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.104 ['0'] Kinyarwanda Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.185 ['2'] Swahili Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.203 ['0'] Twi Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.049 ['2'] Wolof Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.164 ['2'] Yoruba Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.088 ['0'] Zulu Question Answering AfriQA defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.693 ['5'] Arabic Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6']})
# 0.769 [] Czech Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': []})
# 0.807 [] Danish Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.833 ['5'] German Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.877 ['5'] English Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.792 ['5'] Spanish Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.779 ['5'] Finnish Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.831 ['5'] French Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.642 ['3'] Hebrew Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.746 ['4'] Hungarian Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.8 ['4'] Italian Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.709 ['5'] Japanese Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.671 ['4'] Korean Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.804 ['4'] Dutch Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': []})
# 0.79 [] Norwegian Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': []})
# 0.747 ['4'] Polish Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': []})
# 0.83 ['4'] Portuguese Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': []})
# 0.784 ['4'] Russian Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': []})
# 0.817 [] Swedish Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': []})
# 0.557 ['3'] Thai Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': []})
# 0.699 ['4'] Turkish Question Answering Belebele defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': []})
# ...
# 0.957643944 ['5'] Spanish NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.784248842 ['4'] Basque NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.911317009 ['4'] Hindi NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.949702184 ['3'] Indonesian NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.572468564 ['1'] Burmese NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.965585705 ['4'] Russian NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.923229649 ['2'] Swahili NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.731303772 ['1'] Telugu NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# 0.956320318 ['5'] Chinese NLP Applications XstoryCloze defaultdict(<class 'list'>, {'Afrikaans': ['3'], 'Amharic': ['2'], 'Arabic': ['5'], 'Azerbaijani': ['1'], 'Bemba': ['0'], 'Bulgarian': ['3'], 'Bengali': ['3'], 'Welsh': ['1'], 'German': ['5'], 'Greek': ['3'], 'English': ['5'], 'Spanish': ['5'], 'Estonian': ['3'], 'Basque': ['4'], 'Persian': ['4'], 'Finnish': ['5'], 'Fon': ['0'], 'French': ['5'], 'Scottish_gaelic': ['1'], 'Gujarati': ['1'], 'Hausa': ['2'], 'Hebrew': ['3'], 'Hindi': ['4'], 'Haitian Creole': ['0'], 'Hungarian': ['4'], 'Indonesian': ['3'], 'Igbo': ['1'], 'Italian': ['4'], 'Japanese': ['5'], 'Javanese': ['1'], 'Georgian': ['3'], 'Kinyarwanda': ['0'], 'Kazakh': ['3'], 'Kannada': ['1'], 'Korean': ['4'], 'Kyrgyz': ['1'], 'Lithuanian': ['3'], 'Malayalam': ['1'], 'Marathi': ['2'], 'Malay': ['3'], 'Burmese': ['1'], 'Dutch': ['4'], 'Nepali': ['1'], 'Oromo': ['1'], 'Oriya': ['1'], 'Punjabi': ['2'], 'Pidgin': ['0'], 'Polish': ['4'], 'Pashto': ['1'], 'Portuguese': ['4'], 'Quechua': ['1'], 'Kirundi': ['1'], 'Romanian': ['3'], 'Russian': ['4'], 'Sinhala': ['0'], 'Somali': ['1'], 'Serbian_Cyrillic': ['4'], 'Serbian_Latin': ['4'], 'Swahili': ['2'], 'Tamil': ['3'], 'Telugu': ['1'], 'Thai': ['3'], 'Tigrinya': ['2'], 'Tagalog': ['3'], 'Turkish': ['4'], 'Twi': ['0'], 'Ukrainian': ['3'], 'Urdu': ['3'], 'Uzbek': ['3'], 'Vietnamese': ['4'], 'Wolof': ['2'], 'Yoruba': ['2'], 'Chinese': ['5'], 'Chinese_Simplified': ['5'], 'Chinese_Traditional': ['5'], 'Zulu': ['0'], 'English-Hindi': ['6'], 'English-Spanish': ['6'], 'Czech': [], 'Danish': [], 'Norwegian': [], 'Swedish': [], 'Assamese': [], 'Kashmiri': []})
# "\nL[0] #Dataset\nL[2] #Language\nL[4] #Language Code\nL[5] #Language Class\nL[10]#'GPT-3.5-Turbo Monolingual', \nL[11]#'GPT-3.5-Turbo Translate-Test', \nL[12]#'GPT-3.5-Turbo Zero-Shot Cross Lingual', \nL[13]#'GPT-4 Monolingual', \nL[14]#'GPT-4 Translate-Test', \nL[15]#'GPT-4 Zero-Shot Cross Lingual', \nL[16]#'TULRv6', \nL[17]#'BLOOMZ', \nL[18]#'XLM-R', \nL[19]#'mBERT', \nL[20]#'MuRIL', \nL[21]#'XGLM', \nL[22]#'mT5', \nL[23]#'PaLM2 Zero-Shot', \nL[24]#'PaLM2 Monolingual', \nL[25]#'Llama2-7B Monolingual', \nL[26]#'Llama2-13B Monolingual', \nL[27]#'Llama2-70B Monolingual', \nL[28]#'LLaVa-1.5-13B Monolingual', \nL[29]#'LLaVa-1.5-13B Translate-Test'\n"

# %%
'''
Trackwise English language scores for normalization
'''
#all_data[int(class_id[0])][lang][track][dataset] = ele[10]
from termcolor import colored, cprint
import numpy as np

english_norm_scores = dd()

for track in track_dataset:
    cprint(track,"red")
    scores=[]
    for dataset in all_data[5]['English'][track].keys():
        cprint(dataset,"blue")
        print(all_data[5]['English'][track][dataset])
        if (all_data[5]['English'][track][dataset]) != "NA" and (all_data[5]['English'][track][dataset]) != "":
            scores.append(np.double(all_data[5]['English'][track][dataset]))
    if scores:
        if np.sum(scores) > 0.0:
            english_norm_scores[track] = np.mean([e for e in scores if e>0.0])
            print("English score", english_norm_scores[track])
            
print(english_norm_scores)
# Out:
# Dialogue and Interactive Systems
# X-RiSAWOZ
# 0.71667
# English score 0.71667
# Ethics and NLP
# Jigsaw
# 0.0
# WinoMT
# 0.0
# Generation
# PAN-X
# 0.4315197
# English score 0.4315197
# Language Grounding to Vision, Robotics and Beyond
# MARVL
# 0.0
# XM3600
# NA
# Machine Translation and Multilinguality
# IN22
#
# NLP Applications
# XstoryCloze
# 0.967571145
# XCOPA
# 0.978
# English score 0.9727855725
# Question Answering
# Belebele
# 0.877
# AfriQA
# 0.0
# IndicQA
# 0.0
# TyDiQA-GoldP
# 0.5478188
# MLQA
# 0.7276637
# XQuAD
# NA
# English score 0.7174941666666667
# Semantics: Sentence-level Semantics,Textual Inference,and Other Areas
# XNLI
# 0.76247505
# IndicXNLI
# 0.0
# GLUECoS-NLI
# 0.0
# PAWS-X
# 0.724
# English score 0.7432375250000001
# Sentiment Analysis, Stylistic Analysis,and Argument Mining
# GLUECoS-SA
# 0.0
# En-Es-CS
# 0.0
# Summarization
# XLSum
# 0.2587
# English score 0.2587
# Syntax:Tagging,Chunking and Parsing
# UDPOS
# 0.784927536
# English score 0.784927536
# defaultdict(None, {'Dialogue and Interactive Systems': 0.71667, 'Generation': 0.4315197, 'NLP Applications': 0.9727855725, 'Question Answering': 0.7174941666666667, 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': 0.7432375250000001, 'Summarization': 0.2587, 'Syntax:Tagging,Chunking and Parsing': 0.784927536})

# %%
'''
Use: english_norm_scores
'''
from collections import defaultdict as dd

def get_percent_change(lang_score, eng_score):
    if lang_score > eng_score:
        cprint("Invalid assumption", "red")
        print(lang_score, eng_score, 100*np.double(eng_score - lang_score)/np.double(eng_score)) 
    percent_change = np.double(eng_score - lang_score)/np.double(eng_score)
    return percent_change*100

standardized_all_data = dd()
standardized_all_data_missed = dd()

for class_id in all_data.keys():
    standardized_all_data[class_id]=dd()
    standardized_all_data_missed[class_id]=dd()
    for lang in all_data[class_id].keys():
        if lang != "English":
            standardized_all_data[class_id][lang]=dd()
            standardized_all_data_missed[class_id][lang]=dd()
            for track in english_norm_scores.keys():
                standardized_all_data[class_id][lang][track]=dd()
                standardized_all_data_missed[class_id][lang][track]=dd()
                for dataset in all_data[class_id][lang][track].keys():
                    if (all_data[class_id][lang][track][dataset] !='NA') and (all_data[class_id][lang][track][dataset]!='') and np.double(all_data[class_id][lang][track][dataset]) > 0.0:
                        standardized_all_data[class_id][lang][track][dataset] = get_percent_change(np.double(all_data[class_id][lang][track][dataset]), np.double(english_norm_scores[track]))
                    else:
                        standardized_all_data_missed[class_id][lang][track][dataset] = all_data[class_id][lang][track][dataset]
                        #missing_data.append(class_id,lang,track,dataset, all_data[class_id][lang][track][dataset])
            
        #print(class_id, lang, standardized_all_data[class_id][lang])    
       
print(standardized_all_data)
# Out:
# Invalid assumption
# 0.576779026 0.4315197 -33.66226988014683
# Invalid assumption
# 0.798479087 0.784927536 -1.7264716013224501
# Invalid assumption
# 0.577191621 0.4315197 -33.757884286627004
# Invalid assumption
# 0.2734 0.2587 -5.682257441051408
# Invalid assumption
# 0.569037657 0.4315197 -31.86829176049204
# Invalid assumption
# 0.438108814 0.4315197 -1.52695554803176
# Invalid assumption
# 0.516334201 0.4315197 -19.654838701454427
# Invalid assumption
# 0.791476523 0.784927536 -0.8343428787546143
# Invalid assumption
# 0.587242026 0.4315197 -36.086956400831745
# Invalid assumption
# 0.584184639 0.4315197 -35.37844019635719
# Invalid assumption
# 0.2677 0.2587 -3.4789331271743364
# Invalid assumption
# 0.519026397 0.4315197 -20.278725861183155
# Invalid assumption
# 0.5196151 0.4315197 -20.415151382428192
# Invalid assumption
# 0.454849498 0.4315197 -5.406427099388512
# Invalid assumption
# 0.537321477 0.4315197 -24.5184117897746
# Invalid assumption
# 0.746 0.7174941666666667 -3.9729707442453086
# Invalid assumption
# 0.600127959 0.4315197 -39.073131307794306
# Invalid assumption
# 0.8 0.7174941666666667 -11.499164336992294
# Invalid assumption
# 0.593572779 0.4315197 -37.5540395954113
# Invalid assumption
# 0.804 0.7174941666666667 -12.056660158677255
# Invalid assumption
# 0.584175084 0.4315197 -35.376225928966846
# Invalid assumption
# 0.747 0.7174941666666667 -4.112344699666549
# Invalid assumption
# 0.817120088 0.784927536 -4.101340636366723
# Invalid assumption
# 0.489326765 0.4315197 -13.396158970262537
# Invalid assumption
# 0.83 0.7174941666666667 -15.680382999629495
# Invalid assumption
# 0.784 0.7174941666666667 -9.269181050252447
# Invalid assumption
# 0.505335844 0.4315197 -17.10608901517126
# Invalid assumption
# 0.454242312 0.4315197 -5.2657183437975075
# Invalid assumption
# 0.527317373 0.4315197 -22.200069429043452
# Invalid assumption
# 0.833 0.7174941666666667 -16.098504865893215
# Invalid assumption
# 0.806625627 0.784927536 -2.7643432042878384
# Invalid assumption
# 0.601814882 0.4315197 -39.46405737675475
# Invalid assumption
# 0.792 0.7174941666666667 -10.38417269362237
# Invalid assumption
# 0.59141791 0.4315197 -37.05467212736753
# Invalid assumption
# 0.779 0.7174941666666667 -8.572311273146244
# Invalid assumption
# 0.795390925 0.784927536 -1.3330388500983854
# Invalid assumption
# 0.507426493 0.4315197 -17.59057419626496
# Invalid assumption
# 0.831 0.7174941666666667 -15.819756955050735
# Invalid assumption
# 0.2644 0.2587 -2.2033243138770926
# Invalid assumption
# 0.9 0.71667 -25.580811252040686
# Invalid assumption
# 0.776 0.7174941666666667 -8.154189406882523
# Invalid assumption
# 0.763 0.7174941666666667 -6.342327986406397
# Invalid assumption
# 0.7879 0.7432375250000001 -6.009179232439855
# defaultdict(None, {0: defaultdict(None, {'Bemba': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {'AfriQA': 93.86754596146541}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Fon': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {'AfriQA': 85.36573468076976}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Haitian Creole': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {'XCOPA': 25.985744407203367}), 'Question Answering': defaultdict(None, {}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Kinyarwanda': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {'AfriQA': 85.50510863619101}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Pidgin': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {'XLSum': 8.85195206803246}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Sinhala': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {'XLSum': 64.28295322767686}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Twi': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {'AfriQA': 71.70708704948822}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})}), 'Zulu': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {'AfriQA': 87.73509192293085}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {}), 'Syntax:Tagging,Chunking and Parsing': defaultdict(None, {})})}), 1: defaultdict(None, {'Azerbaijani': defaultdict(None, {'Dialogue and Interactive Systems': defaultdict(None, {}), 'Generation': defaultdict(None, {'PAN-X': 2.4614285280602504}), 'NLP Applications': defaultdict(None, {}), 'Question Answering': defaultdict(None, {}), 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': defaultdict(None, {}), 'Summarization': defaultdict(None, {'XLSum': 38.925396211828364}), 'Synt ...

# %%
for class_id in standardized_all_data.keys():
    for lang in standardized_all_data[class_id].keys():
        for track in standardized_all_data[class_id][lang].keys():
            if standardized_all_data[class_id][lang][track].keys():
                for dataset in standardized_all_data[class_id][lang][track].keys():
                    print(class_id, lang, track, dataset, standardized_all_data[class_id][lang][track][dataset])
# Out:
# 0 Bemba Question Answering AfriQA 93.86754596146541
# 0 Fon Question Answering AfriQA 85.36573468076976
# 0 Haitian Creole NLP Applications XCOPA 25.985744407203367
# 0 Kinyarwanda Question Answering AfriQA 85.50510863619101
# 0 Pidgin Summarization XLSum 8.85195206803246
# 0 Sinhala Summarization XLSum 64.28295322767686
# 0 Twi Question Answering AfriQA 71.70708704948822
# 0 Zulu Question Answering AfriQA 87.73509192293085
# 1 Azerbaijani Generation PAN-X 2.4614285280602504
# 1 Azerbaijani Summarization XLSum 38.925396211828364
# 1 Welsh Summarization XLSum 15.384615384615374
# 1 Scottish_gaelic Summarization XLSum 10.398144568998834
# 1 Gujarati Generation PAN-X 57.37353219331586
# 1 Gujarati Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 31.894231928077097
# 1 Igbo Question Answering AfriQA 71.42833913864574
# 1 Igbo Summarization XLSum 26.555856204097406
# 1 Javanese Generation PAN-X -33.66226988014683
# 1 Kannada Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 27.4630602107987
# 1 Kyrgyz Summarization XLSum 53.382296095863936
# 1 Malayalam Generation PAN-X 41.49952899021759
# 1 Malayalam Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 34.82149088207031
# 1 Burmese Generation PAN-X 79.88679242222314
# 1 Burmese NLP Applications XstoryCloze 41.1516185906427
# 1 Burmese Summarization XLSum 70.23579435639736
# 1 Nepali Summarization XLSum 39.19597989949749
# 1 Oromo Summarization XLSum 44.375724777734824
# 1 Oriya Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 36.191125844998204
# 1 Pashto Summarization XLSum 17.510630073444137
# 1 Quechua Generation PAN-X 2.8740409765765094
# 1 Quechua NLP Applications XCOPA 43.872522842129214
# 1 Kirundi Summarization XLSum 20.718979512949357
# 1 Somali Summarization XLSum 17.89717819868573
# 1 Telugu Generation PAN-X 49.049890422152224
# 1 Telugu NLP Applications XstoryCloze 24.823744032244065
# 1 Telugu Question Answering TyDiQA-GoldP 1.1862349635827412
# 1 Telugu Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 36.21798145888827
# 1 Telugu Summarization XLSum 97.56474681097795
# 1 Telugu Syntax:Tagging,Chunking and Parsing UDPOS -1.7264716013224501
# 2 Amharic Summarization XLSum 63.6644762272903
# 2 Hausa Question Answering AfriQA 84.39011699282108
# 2 Hausa Summarization XLSum 8.310784692694236
# 2 Marathi Generation PAN-X 20.23495775511524
# 2 Marathi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 32.8878887001837
# 2 Marathi Summarization XLSum 46.57904909161191
# 2 Marathi Syntax:Tagging,Chunking and Parsing UDPOS 26.17219139067125
# 2 Punjabi Generation PAN-X 14.908288080474657
# 2 Punjabi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 27.839038401619998
# 2 Punjabi Summarization XLSum 11.403169694626982
# 2 Swahili Generation PAN-X -33.757884286627004
# 2 Swahili NLP Applications XstoryCloze 5.094228872313989
# 2 Swahili NLP Applications XCOPA 15.705986685981616
# 2 Swahili Question Answering AfriQA 74.21581824707054
# 2 Swahili Question Answering TyDiQA-GoldP 10.381807982178714
# 2 Swahili Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 24.240389773107864
# 2 Swahili Summarization XLSum -5.682257441051408
# 2 Wolof Question Answering AfriQA 93.17067618435921
# 2 Wolof Syntax:Tagging,Chunking and Parsing UDPOS 35.82820784108662
# 2 Yoruba Generation PAN-X -31.868291760492042
# 2 Yoruba Question Answering AfriQA 77.14267131091658
# 2 Yoruba Summarization XLSum 36.21955933513722
# 2 Yoruba Syntax:Tagging,Chunking and Parsing UDPOS 91.12082570638724
# 3 Afrikaans Generation PAN-X -1.52695554803176
# 3 Afrikaans Syntax:Tagging,Chunking and Parsing UDPOS 5.298388716484017
# 3 Bulgarian Generation PAN-X -19.654838701454427
# 3 Bulgarian Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 14.545522846145326
# 3 Bulgarian Syntax:Tagging,Chunking and Parsing UDPOS -0.8343428787546143
# 3 Bengali Generation PAN-X 6.669903598839172
# 3 Bengali Question Answering TyDiQA-GoldP 15.403590969961432
# 3 Bengali Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 27.919605108743685
# 3 Bengali Summarization XLSum 33.784306146115185
# 3 Greek Generation PAN-X 4.956663855671022
# 3 Greek Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 12.423931501574828
# 3 Greek Syntax:Tagging,Chunking and Parsing UDPOS 40.00668795495027
# 3 Estonian Generation PAN-X -36.08695640083175
# 3 Estonian NLP Applications XCOPA 6.865395045730898
# 3 Estonian Syntax:Tagging,Chunking and Parsing UDPOS 3.2019258909016046
# 3 Hebrew Generation PAN-X 20.52178567977313
# 3 Hebrew Question Answering Belebele 10.521920619563687
# 3 Hebrew Syntax:Tagging,Chunking and Parsing UDPOS 31.45822406209992
# 3 Indonesian Generation PAN-X -35.37844019635719
# 3 Indonesian NLP Applications XstoryCloze 2.372916411648367
# 3 Indonesian NLP Applications XCOPA 7.070990200155333
# 3 Indonesian Question Answering TyDiQA-GoldP 6.392604817925348
# 3 Indonesian Summarization XLSum -3.4789331271743364
# 3 Indonesian Syntax:Tagging,Chunking and Parsing UDPOS 18.92030578476227
# 3 Georgian Generation PAN-X 41.88616950744079
# 3 Kazakh Generation PAN-X 28.319938579860903
# 3 Kazakh Syntax:Tagging,Chunking and Parsing UDPOS 17.476369818678393
# 3 Lithuanian Generation PAN-X -20.278725861183155
# 3 Lithuanian Syntax:Tagging,Chunking and Parsing UDPOS 9.1509406544759
# 3 Malay Generation PAN-X -20.415151382428192
# 3 Romanian Generation PAN-X 1.1309052634213412
# 3 Romanian Syntax:Tagging,Chunking and Parsing UDPOS 15.077763687984572
# 3 Tamil Generation PAN-X 39.77811882053125
# 3 Tamil NLP Applications XCOPA 39.34942944479165
# 3 Tamil Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 35.197469072891614
# 3 Tamil Syntax:Tagging,Chunking and Parsing UDPOS 58.43207556933001
# 3 Thai Generation PAN-X 96.13559682211495
# 3 Thai NLP Applications XCOPA 20.22908008331918
# 3 Thai Question Answering Belebele 22.368706830369113
# 3 Thai Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 27.355637755238483
# 3 Thai Summarization XLSum 65.67452647854658
# 3 Thai Syntax:Tagging,Chunking and Parsing UDPOS 67.50703901920446
# 3 Tagalog Generation PAN-X 15.45917115719167
# 3 Tagalog Syntax:Tagging,Chunking and Parsing UDPOS 30.833464861398358
# 3 Ukrainian Generation PAN-X 20.366110515927776
# 3 Ukrainian Summarization XLSum 30.76923076923076
# 3 Ukrainian Syntax:Tagging,Chunking and Parsing UDPOS 24.956490633295854
# 3 Urdu Generation PAN-X 17.301658533781886
# 3 Urdu Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 33.962112179413985
# 3 Urdu Summarization XLSum 1.2369540007730888
# 3 Urdu Syntax:Tagging,Chunking and Parsing UDPOS 49.200583020443304
# 3 Uzbek Summarization XLSum 54.46463084654039
# 4 Basque Generation PAN-X 26.969728380882728
# 4 Basque NLP Applications XstoryCloze 19.3811191109128
# 4 Basque Syntax:Tagging,Chunking and Parsing UDPOS 8.266047122087453
# 4 Persian Generation PAN-X 8.907982648300882
# 4 Persian Summarization XLSum 11.016621569385388
# 4 Persian Syntax:Tagging,Chunking and Parsing UDPOS 40.54003043664402
# 4 Hindi Dialogue and Interactive Systems X-RiSAWOZ 86.04657652755104
# 4 Hindi Generation PAN-X -5.406427099388513
# 4 Hindi NLP Applications XstoryCloze 6.318819402515344
# 4 Hindi Question Answering MLQA 29.27000335658942
# 4 Hindi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 25.341468731681715
# 4 Hindi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 25.368324345571757
# 4 Hindi Summarization XLSum 8.735987630459984
# 4 Hindi Syntax:Tagging,Chunking and Parsing UDPOS 35.42692621245994
# 4 Hungarian Generation PAN-X -24.5184117897746
# 4 Hungarian Question Answering Belebele -3.9729707442453086
# 4 Hungarian Syntax:Tagging,Chunking and Parsing UDPOS 16.638896842064668
# 4 Italian Generation PAN-X -39.0731313077943
# 4 Italian NLP Applications XCOPA 2.1367064939688976
# 4 Italian Question Answering Belebele -11.499164336992294
# 4 Italian Syntax:Tagging,Chunking and Parsing UDPOS 3.9857922629943268
# 4 Korean Dialogue and Interactive Systems X-RiSAWOZ 53.48905353928587
# 4 Korean Generation PAN-X 35.28547016509327
# 4 Korean Question Answering Belebele 6.480075912347711
# 4 Korean Question Answering TyDiQA-GoldP 16.82322620509109
# 4 Korean Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 10.593857596197134
# 4 Korean Summarization XLSum 43.21608040201005
# 4 Korean Syntax:Tagging,Chunking and Parsing UDPOS 50.28768884978957
# 4 Dutch Generation PAN-X -37.5540395954113
# 4 Dutch Question Answering Belebele -12.056660158677257
# 4 Dutch Syntax:Tagging,Chunking and Parsing UDPOS 0.27712023087950627
# 4 Polish Generation PAN-X -35.376225928966846
# 4 Polish Question Answering Belebele -4.11234469966655
# 4 Polish Syntax:Tagging,Chunking and Parsing UDPOS -4.101340636366723
# 4 Portuguese Generation PAN-X -13.396158970262537
# 4 Portuguese Question Answering Belebele -15.680382999629494
# 4 Portuguese Summarization XLSum 3.826826439891764
# 4 Portuguese Syntax:Tagging,Chunking and Parsing UDPOS 2.3474079013581615
# 4 Russian Generation PAN-X 31.981006197399566
# 4 Russian NLP Applications XstoryCloze 0.740128935248987
# 4 Russian Question Answering Belebele -9.269181050252447
# 4 Russian Question Answering TyDiQA-GoldP 36.19442202201411
# 4 Russian Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 15.91515780907323
# 4 Russian Syntax:Tagging,Chunking and Parsing UDPOS 10.983126855164887
# 4 Serbian_Cyrillic Summarization XLSum 56.93853884808659
# 4 Serbian_Latin Summarization XLSum 35.52377270970235
# 4 Turkish Generation PAN-X -17.106089015171257
# 4 Turkish NLP Applications XCOPA 6.454204736882027
# 4 Turkish Question Answering Belebele 2.577605160552994
# 4 Turkish Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 15.754024260279378
# 4 Turkish Summarization XLSum 14.882102821801308
# 4 Turkish Syntax:Tagging,Chunking and Parsing UDPOS 1.5846499746187945
# 4 Vietnamese Generation PAN-X 22.328316181161604
# 4 Vietnamese Question Answering MLQA 17.862802601182583
# 4 Vietnamese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 18.09046038142384
# 4 Vietnamese Summarization XLSum 19.250096637031305
# 4 Vietnamese Syntax:Tagging,Chunking and Parsing UDPOS 26.528087938043754
# 5 Arabic Generation PAN-X -5.265718343797508
# 5 Arabic NLP Applications XstoryCloze 4.958163223581314
# 5 Arabic Question Answering Belebele 3.4138488930804374
# 5 Arabic Question Answering TyDiQA-GoldP 29.127242614051447
# 5 Arabic Question Answering MLQA 32.45657978636295
# 5 Arabic Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 20.641741144595745
# 5 Arabic Summarization XLSum 4.213374565133356
# 5 Arabic Syntax:Tagging,Chunking and Parsing UDPOS 51.14570397744333
# 5 German Generation PAN-X -22.200069429043452
# 5 German Question Answering Belebele -16.098504865893215
# 5 German Question Answering MLQA 28.907157201045774
# 5 German Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 9.416105840457938
# 5 German Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 5.077451518611099
# 5 German Syntax:Tagging,Chunking and Parsing UDPOS -2.7643432042878384
# 5 Spanish Generation PAN-X -39.46405737675475
# 5 Spanish NLP Applications XstoryCloze 1.5565227248474642
# 5 Spanish Question Answering Belebele -10.38417269362237
# 5 Spanish Question Answering MLQA 24.983181047929538
# 5 Spanish Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 5.3877677933443975
# 5 Spanish Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 3.193800662850013
# 5 Spanish Summarization XLSum 20.21646695013529
# 5 Spanish Syntax:Tagging,Chunking and Parsing UDPOS 55.71985755892758
# 5 Finnish Generation PAN-X -37.054672127367525
# 5 Finnish Question Answering Belebele -8.572311273146244
# 5 Finnish Question Answering TyDiQA-GoldP 7.235343376775423
# 5 Finnish Syntax:Tagging,Chunking and Parsing UDPOS -1.3330388500983854
# 5 French Dialogue and Interactive Systems X-RiSAWOZ 11.628783121938978
# 5 French Generation PAN-X -17.59057419626496
# 5 French Question Answering Belebele -15.819756955050735
# 5 French Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 8.905849714732863
# 5 French Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 2.9919809283041903
# 5 French Summarization XLSum 0.115964437572465
# 5 French Syntax:Tagging,Chunking and Parsing UDPOS 0.5818377863609511
# 5 Japanese Generation PAN-X 82.93775116176619
# 5 Japanese Question Answering Belebele 1.1838656063405892
# 5 Japanese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 9.584758923467975
# 5 Japanese Summarization XLSum -2.2033243138770926
# 5 Japanese Syntax:Tagging,Chunking and Parsing UDPOS 39.611416180461276
# 5 Chinese Dialogue and Interactive Systems X-RiSAWOZ -25.580811252040686
# 5 Chinese Generation PAN-X 69.08730980300551
# 5 Chinese NLP Applications XstoryCloze 1.6925882707825652
# 5 Chinese Question Answering MLQA 20.96451422950012
# 5 Chinese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 16.425413934798307
# 5 Chinese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 6.961102374372184
# 5 Chinese Summarization XLSum 9.393119443370695
# 5 Chinese Syntax:Tagging,Chunking and Parsing UDPOS 27.139631523896497
# 5 Chinese_Simplified Question Answering Belebele -8.154189406882523
# 5 Chinese_Simplified Summarization XLSum 16.814843448009274
# 5 Chinese_Traditional Question Answering Belebele -6.3423279864063975
# 6 English-Hindi Dialogue and Interactive Systems X-RiSAWOZ 62.79040562602034
# 6 English-Hindi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas GLUECoS-NLI -6.0091792324398545

# %%
class_wise_readiness_score = dd(list)
track_wise_readiness_score = dd(list)
for class_id in standardized_all_data.keys():
    for lang in standardized_all_data[class_id].keys():
        for track in standardized_all_data[class_id][lang].keys():
            if standardized_all_data[class_id][lang][track].keys():
                for dataset in standardized_all_data[class_id][lang][track].keys():
                    #print(class_id, lang, track, dataset, standardized_all_data[class_id][lang][track][dataset])
                    class_wise_readiness_score[class_id].append(np.double(standardized_all_data[class_id][lang][track][dataset]))
                    track_wise_readiness_score[track].append(np.double(standardized_all_data[class_id][lang][track][dataset]))

print("Overall Score");x=[]
for ele in class_wise_readiness_score.keys():
    x.append(np.mean(class_wise_readiness_score[ele]))
print(np.mean(x))

print(class_wise_readiness_score)
for ele in class_wise_readiness_score.keys():
    print(ele, np.mean(class_wise_readiness_score[ele]))
    
print(track_wise_readiness_score)
for ele in track_wise_readiness_score.keys():
    print(ele, np.mean(track_wise_readiness_score[ele]))
# Out:
# 0 Bemba Question Answering AfriQA 93.86754596146541
# 0 Fon Question Answering AfriQA 85.36573468076976
# 0 Haitian Creole NLP Applications XCOPA 25.985744407203367
# 0 Kinyarwanda Question Answering AfriQA 85.50510863619101
# 0 Pidgin Summarization XLSum 8.85195206803246
# 0 Sinhala Summarization XLSum 64.28295322767686
# 0 Twi Question Answering AfriQA 71.70708704948822
# 0 Zulu Question Answering AfriQA 87.73509192293085
# 1 Azerbaijani Generation PAN-X 2.4614285280602504
# 1 Azerbaijani Summarization XLSum 38.925396211828364
# 1 Welsh Summarization XLSum 15.384615384615374
# 1 Scottish_gaelic Summarization XLSum 10.398144568998834
# 1 Gujarati Generation PAN-X 57.37353219331586
# 1 Gujarati Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 31.894231928077097
# 1 Igbo Question Answering AfriQA 71.42833913864574
# 1 Igbo Summarization XLSum 26.555856204097406
# 1 Javanese Generation PAN-X -33.66226988014683
# 1 Kannada Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 27.4630602107987
# 1 Kyrgyz Summarization XLSum 53.382296095863936
# 1 Malayalam Generation PAN-X 41.49952899021759
# 1 Malayalam Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 34.82149088207031
# 1 Burmese Generation PAN-X 79.88679242222314
# 1 Burmese NLP Applications XstoryCloze 41.1516185906427
# 1 Burmese Summarization XLSum 70.23579435639736
# 1 Nepali Summarization XLSum 39.19597989949749
# 1 Oromo Summarization XLSum 44.375724777734824
# 1 Oriya Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 36.191125844998204
# 1 Pashto Summarization XLSum 17.510630073444137
# 1 Quechua Generation PAN-X 2.8740409765765094
# 1 Quechua NLP Applications XCOPA 43.872522842129214
# 1 Kirundi Summarization XLSum 20.718979512949357
# 1 Somali Summarization XLSum 17.89717819868573
# 1 Telugu Generation PAN-X 49.049890422152224
# 1 Telugu NLP Applications XstoryCloze 24.823744032244065
# 1 Telugu Question Answering TyDiQA-GoldP 1.1862349635827412
# 1 Telugu Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 36.21798145888827
# 1 Telugu Summarization XLSum 97.56474681097795
# 1 Telugu Syntax:Tagging,Chunking and Parsing UDPOS -1.7264716013224501
# 2 Amharic Summarization XLSum 63.6644762272903
# 2 Hausa Question Answering AfriQA 84.39011699282108
# 2 Hausa Summarization XLSum 8.310784692694236
# 2 Marathi Generation PAN-X 20.23495775511524
# 2 Marathi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 32.8878887001837
# 2 Marathi Summarization XLSum 46.57904909161191
# 2 Marathi Syntax:Tagging,Chunking and Parsing UDPOS 26.17219139067125
# 2 Punjabi Generation PAN-X 14.908288080474657
# 2 Punjabi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 27.839038401619998
# 2 Punjabi Summarization XLSum 11.403169694626982
# 2 Swahili Generation PAN-X -33.757884286627004
# 2 Swahili NLP Applications XstoryCloze 5.094228872313989
# 2 Swahili NLP Applications XCOPA 15.705986685981616
# 2 Swahili Question Answering AfriQA 74.21581824707054
# 2 Swahili Question Answering TyDiQA-GoldP 10.381807982178714
# 2 Swahili Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 24.240389773107864
# 2 Swahili Summarization XLSum -5.682257441051408
# 2 Wolof Question Answering AfriQA 93.17067618435921
# 2 Wolof Syntax:Tagging,Chunking and Parsing UDPOS 35.82820784108662
# 2 Yoruba Generation PAN-X -31.868291760492042
# 2 Yoruba Question Answering AfriQA 77.14267131091658
# 2 Yoruba Summarization XLSum 36.21955933513722
# 2 Yoruba Syntax:Tagging,Chunking and Parsing UDPOS 91.12082570638724
# 3 Afrikaans Generation PAN-X -1.52695554803176
# 3 Afrikaans Syntax:Tagging,Chunking and Parsing UDPOS 5.298388716484017
# 3 Bulgarian Generation PAN-X -19.654838701454427
# 3 Bulgarian Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 14.545522846145326
# 3 Bulgarian Syntax:Tagging,Chunking and Parsing UDPOS -0.8343428787546143
# 3 Bengali Generation PAN-X 6.669903598839172
# 3 Bengali Question Answering TyDiQA-GoldP 15.403590969961432
# 3 Bengali Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 27.919605108743685
# 3 Bengali Summarization XLSum 33.784306146115185
# 3 Greek Generation PAN-X 4.956663855671022
# 3 Greek Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 12.423931501574828
# 3 Greek Syntax:Tagging,Chunking and Parsing UDPOS 40.00668795495027
# 3 Estonian Generation PAN-X -36.08695640083175
# 3 Estonian NLP Applications XCOPA 6.865395045730898
# 3 Estonian Syntax:Tagging,Chunking and Parsing UDPOS 3.2019258909016046
# 3 Hebrew Generation PAN-X 20.52178567977313
# 3 Hebrew Question Answering Belebele 10.521920619563687
# 3 Hebrew Syntax:Tagging,Chunking and Parsing UDPOS 31.45822406209992
# 3 Indonesian Generation PAN-X -35.37844019635719
# 3 Indonesian NLP Applications XstoryCloze 2.372916411648367
# 3 Indonesian NLP Applications XCOPA 7.070990200155333
# 3 Indonesian Question Answering TyDiQA-GoldP 6.392604817925348
# 3 Indonesian Summarization XLSum -3.4789331271743364
# 3 Indonesian Syntax:Tagging,Chunking and Parsing UDPOS 18.92030578476227
# 3 Georgian Generation PAN-X 41.88616950744079
# 3 Kazakh Generation PAN-X 28.319938579860903
# 3 Kazakh Syntax:Tagging,Chunking and Parsing UDPOS 17.476369818678393
# 3 Lithuanian Generation PAN-X -20.278725861183155
# 3 Lithuanian Syntax:Tagging,Chunking and Parsing UDPOS 9.1509406544759
# 3 Malay Generation PAN-X -20.415151382428192
# 3 Romanian Generation PAN-X 1.1309052634213412
# 3 Romanian Syntax:Tagging,Chunking and Parsing UDPOS 15.077763687984572
# 3 Tamil Generation PAN-X 39.77811882053125
# 3 Tamil NLP Applications XCOPA 39.34942944479165
# 3 Tamil Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 35.197469072891614
# 3 Tamil Syntax:Tagging,Chunking and Parsing UDPOS 58.43207556933001
# 3 Thai Generation PAN-X 96.13559682211495
# 3 Thai NLP Applications XCOPA 20.22908008331918
# 3 Thai Question Answering Belebele 22.368706830369113
# 3 Thai Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 27.355637755238483
# 3 Thai Summarization XLSum 65.67452647854658
# 3 Thai Syntax:Tagging,Chunking and Parsing UDPOS 67.50703901920446
# 3 Tagalog Generation PAN-X 15.45917115719167
# 3 Tagalog Syntax:Tagging,Chunking and Parsing UDPOS 30.833464861398358
# 3 Ukrainian Generation PAN-X 20.366110515927776
# 3 Ukrainian Summarization XLSum 30.76923076923076
# 3 Ukrainian Syntax:Tagging,Chunking and Parsing UDPOS 24.956490633295854
# 3 Urdu Generation PAN-X 17.301658533781886
# 3 Urdu Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 33.962112179413985
# 3 Urdu Summarization XLSum 1.2369540007730888
# 3 Urdu Syntax:Tagging,Chunking and Parsing UDPOS 49.200583020443304
# 3 Uzbek Summarization XLSum 54.46463084654039
# 4 Basque Generation PAN-X 26.969728380882728
# 4 Basque NLP Applications XstoryCloze 19.3811191109128
# 4 Basque Syntax:Tagging,Chunking and Parsing UDPOS 8.266047122087453
# 4 Persian Generation PAN-X 8.907982648300882
# 4 Persian Summarization XLSum 11.016621569385388
# 4 Persian Syntax:Tagging,Chunking and Parsing UDPOS 40.54003043664402
# 4 Hindi Dialogue and Interactive Systems X-RiSAWOZ 86.04657652755104
# 4 Hindi Generation PAN-X -5.406427099388513
# 4 Hindi NLP Applications XstoryCloze 6.318819402515344
# 4 Hindi Question Answering MLQA 29.27000335658942
# 4 Hindi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 25.341468731681715
# 4 Hindi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas IndicXNLI 25.368324345571757
# 4 Hindi Summarization XLSum 8.735987630459984
# 4 Hindi Syntax:Tagging,Chunking and Parsing UDPOS 35.42692621245994
# 4 Hungarian Generation PAN-X -24.5184117897746
# 4 Hungarian Question Answering Belebele -3.9729707442453086
# 4 Hungarian Syntax:Tagging,Chunking and Parsing UDPOS 16.638896842064668
# 4 Italian Generation PAN-X -39.0731313077943
# 4 Italian NLP Applications XCOPA 2.1367064939688976
# 4 Italian Question Answering Belebele -11.499164336992294
# 4 Italian Syntax:Tagging,Chunking and Parsing UDPOS 3.9857922629943268
# 4 Korean Dialogue and Interactive Systems X-RiSAWOZ 53.48905353928587
# 4 Korean Generation PAN-X 35.28547016509327
# 4 Korean Question Answering Belebele 6.480075912347711
# 4 Korean Question Answering TyDiQA-GoldP 16.82322620509109
# 4 Korean Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 10.593857596197134
# 4 Korean Summarization XLSum 43.21608040201005
# 4 Korean Syntax:Tagging,Chunking and Parsing UDPOS 50.28768884978957
# 4 Dutch Generation PAN-X -37.5540395954113
# 4 Dutch Question Answering Belebele -12.056660158677257
# 4 Dutch Syntax:Tagging,Chunking and Parsing UDPOS 0.27712023087950627
# 4 Polish Generation PAN-X -35.376225928966846
# 4 Polish Question Answering Belebele -4.11234469966655
# 4 Polish Syntax:Tagging,Chunking and Parsing UDPOS -4.101340636366723
# 4 Portuguese Generation PAN-X -13.396158970262537
# 4 Portuguese Question Answering Belebele -15.680382999629494
# 4 Portuguese Summarization XLSum 3.826826439891764
# 4 Portuguese Syntax:Tagging,Chunking and Parsing UDPOS 2.3474079013581615
# 4 Russian Generation PAN-X 31.981006197399566
# 4 Russian NLP Applications XstoryCloze 0.740128935248987
# 4 Russian Question Answering Belebele -9.269181050252447
# 4 Russian Question Answering TyDiQA-GoldP 36.19442202201411
# 4 Russian Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 15.91515780907323
# 4 Russian Syntax:Tagging,Chunking and Parsing UDPOS 10.983126855164887
# 4 Serbian_Cyrillic Summarization XLSum 56.93853884808659
# 4 Serbian_Latin Summarization XLSum 35.52377270970235
# 4 Turkish Generation PAN-X -17.106089015171257
# 4 Turkish NLP Applications XCOPA 6.454204736882027
# 4 Turkish Question Answering Belebele 2.577605160552994
# 4 Turkish Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 15.754024260279378
# 4 Turkish Summarization XLSum 14.882102821801308
# 4 Turkish Syntax:Tagging,Chunking and Parsing UDPOS 1.5846499746187945
# 4 Vietnamese Generation PAN-X 22.328316181161604
# 4 Vietnamese Question Answering MLQA 17.862802601182583
# 4 Vietnamese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 18.09046038142384
# 4 Vietnamese Summarization XLSum 19.250096637031305
# 4 Vietnamese Syntax:Tagging,Chunking and Parsing UDPOS 26.528087938043754
# 5 Arabic Generation PAN-X -5.265718343797508
# 5 Arabic NLP Applications XstoryCloze 4.958163223581314
# 5 Arabic Question Answering Belebele 3.4138488930804374
# 5 Arabic Question Answering TyDiQA-GoldP 29.127242614051447
# 5 Arabic Question Answering MLQA 32.45657978636295
# 5 Arabic Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 20.641741144595745
# 5 Arabic Summarization XLSum 4.213374565133356
# 5 Arabic Syntax:Tagging,Chunking and Parsing UDPOS 51.14570397744333
# 5 German Generation PAN-X -22.200069429043452
# 5 German Question Answering Belebele -16.098504865893215
# 5 German Question Answering MLQA 28.907157201045774
# 5 German Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 9.416105840457938
# 5 German Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 5.077451518611099
# 5 German Syntax:Tagging,Chunking and Parsing UDPOS -2.7643432042878384
# 5 Spanish Generation PAN-X -39.46405737675475
# 5 Spanish NLP Applications XstoryCloze 1.5565227248474642
# 5 Spanish Question Answering Belebele -10.38417269362237
# 5 Spanish Question Answering MLQA 24.983181047929538
# 5 Spanish Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 5.3877677933443975
# 5 Spanish Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 3.193800662850013
# 5 Spanish Summarization XLSum 20.21646695013529
# 5 Spanish Syntax:Tagging,Chunking and Parsing UDPOS 55.71985755892758
# 5 Finnish Generation PAN-X -37.054672127367525
# 5 Finnish Question Answering Belebele -8.572311273146244
# 5 Finnish Question Answering TyDiQA-GoldP 7.235343376775423
# 5 Finnish Syntax:Tagging,Chunking and Parsing UDPOS -1.3330388500983854
# 5 French Dialogue and Interactive Systems X-RiSAWOZ 11.628783121938978
# 5 French Generation PAN-X -17.59057419626496
# 5 French Question Answering Belebele -15.819756955050735
# 5 French Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 8.905849714732863
# 5 French Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 2.9919809283041903
# 5 French Summarization XLSum 0.115964437572465
# 5 French Syntax:Tagging,Chunking and Parsing UDPOS 0.5818377863609511
# 5 Japanese Generation PAN-X 82.93775116176619
# 5 Japanese Question Answering Belebele 1.1838656063405892
# 5 Japanese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 9.584758923467975
# 5 Japanese Summarization XLSum -2.2033243138770926
# 5 Japanese Syntax:Tagging,Chunking and Parsing UDPOS 39.611416180461276
# 5 Chinese Dialogue and Interactive Systems X-RiSAWOZ -25.580811252040686
# 5 Chinese Generation PAN-X 69.08730980300551
# 5 Chinese NLP Applications XstoryCloze 1.6925882707825652
# 5 Chinese Question Answering MLQA 20.96451422950012
# 5 Chinese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas XNLI 16.425413934798307
# 5 Chinese Semantics: Sentence-level Semantics,Textual Inference,and Other Areas PAWS-X 6.961102374372184
# 5 Chinese Summarization XLSum 9.393119443370695
# 5 Chinese Syntax:Tagging,Chunking and Parsing UDPOS 27.139631523896497
# 5 Chinese_Simplified Question Answering Belebele -8.154189406882523
# 5 Chinese_Simplified Summarization XLSum 16.814843448009274
# 5 Chinese_Traditional Question Answering Belebele -6.3423279864063975
# 6 English-Hindi Dialogue and Interactive Systems X-RiSAWOZ 62.79040562602034
# 6 English-Hindi Semantics: Sentence-level Semantics,Textual Inference,and Other Areas GLUECoS-NLI -6.0091792324398545
# defaultdict(<class 'list'>, {0: [93.86754596146541, 85.36573468076976, 25.985744407203367, 85.50510863619101, 8.85195206803246, 64.28295322767686, 71.70708704948822, 87.73509192293085], 1: [2.4614285280602504, 38.925396211828364, 15.384615384615374, 10.398144568998834, 57.37353219331586, 31.894231928077097, 71.42833913864574, 26.555856204097406, -33.66226988014683, 27.4630602107987, 53.382296095863936, 41.49952899021759, 34.82149088207031, 79.88679242222314, 41.1516185906427, 70.23579435639736, 39.19597989949749, 44.375724777734824, 36.191125844998204, 17.510630073444137, 2.8740409765765094, 43.872522842129214, 20.718979512949357, 17.89717819868573, 49.049890422152224, 24.823744032244065, 1.1862349635827412, 36.21798145888827, 97.56474681097795, -1.7264716013224501], 2: [63.6644762272903, 84.39011699282108, 8.310784692694236, 20.23495775511524, 32.8878887001837, 46.57904909161191, 26.17219139067125, 14.908288080474657, 27.839038401619998, 11.403169694626982, -33.757884286627004, 5.094228872313989, 15.705986685981616, 74.21581824707054, 10.381807982178714, 24.240389773107864, -5.682257441051408, 93.17067618435921, 35.82820784108662, -31.868291760492042, 77.14267131091658, 36.21955933513722, 91.12082570638724], 3: [-1.52695554803176, 5.298388716484017, -19.654838701454427, 14.545522846145326, -0.8343428787546143, 6.669903598839172, 15.403590969961432, 27.919605108743685, 33.784306146115185, 4.956663855671022, 12.423931501574828, 40.00668795495027, -36.08695640083175, 6.865395045730898, 3.2019258909016046, 20.52178567977313, 10.521920619563687, 31.45822406209992, -35.37844019635719, 2.372916411648367, 7.070990200155333, 6.392604817925348, -3.4789331271743364, 18.92030578476227, 41.88616950744079, 28.319938579860903, 17.476369818678393, -20.278725861183155, 9.1509406544759, -20.415151382428192, 1.1309052634213412, 15.077763687984572, 39.77811882053125, 39.34942944479165, 35.197469072891614, 58.43207556933001, 96.13559682211495, 20.22908008331918, 22.368706830369113, 27.355637755238483, 65.67452647854658, 67.50703901920446, 15.45917115719167, 30.833464861398358, 20.366110515927776, 30.76923076923076, 24.956490633295854, 17.301658533781886, 33.962112179413985, 1.2369540007730888, 49.200583020443304, 54.46463084654039], 4: [26.969728380882728, 19.3811191109128, 8.266047122087453, 8.907982648300882, 11.016621569385388, 40.54003043664402, 86.04657652755104, -5.406427099388513, 6.318819402515344, 29.27000335658942, 25.341468731681715, 25.368324345571757, 8.735987630459984, 35.42692621245994, -24.5184117897746, -3.9729707442453086, 16.638896842064668, -39.0731313077943, 2.1367064939688976, -11.499164336992294, 3.9857922629943268, 53.48905353928587, 35.28547016509327, 6.480075912347711, 16.82322620509109, 10.593857596197134, 43.21608040201005, 50.28768884978957, -37.5540395954113, -12.056660158677257, 0.27712023087950627, -35.376225928966846, -4.11234469966655, -4.101340636366723, -13.396158970262537, -15.680382999629494, 3.826826439891764, 2.3474079013581615, 31.981006197399566, 0.740128935248987, -9.269181050252447, 36.19442202201411, 15.91515780907323, 10.983126855164887, 56.93853884808659, 35.52377270970235, -17.106089015171257, 6.454204736882027, 2.577605160552994, 15.754024260279378, 14.882102821801308, 1.5846499746187945, 22.328316181161604, 17.862802601182583, 18.09046038142384, 19.250096637031305, 26.528087938043754], 5: [-5.265718343797508, 4.958163223581314, 3.4138488930804374, 29.127242614051447, 32.45657978636295, 20.641741144595745, 4.213374565133356, 51.14570397744333, -22.200069429043452, -16.098504865893215, 28.907157201045774, 9.416105840457938, 5.077451518611099, -2.7643432042878384, -39.46405737675475, 1.5565227248474642, -10.38417269362237, 24.983181047929538, 5.3877677933443975, 3.193800662850013, 20.21646695013529, 55.71985755892758, -37.054672127367525, -8.572311273146244, 7.235343376775423, -1.3330388500983854, 11.628783121938978, -17.59057419626496, -15.819756955050735, 8.905849714732863, 2.9919809283041903, 0.11 ...
# 0 65.41265224421974
# 1 33.298405467941464
# 2 31.66094345554254
# 3 19.12116344309666
# 4 11.884979193913727
# 5 8.466187091700409
# 6 28.39061319679024
# defaultdict(<class 'list'>, {'Question Answering': [93.86754596146541, 85.36573468076976, 85.50510863619101, 71.70708704948822, 87.73509192293085, 71.42833913864574, 1.1862349635827412, 84.39011699282108, 74.21581824707054, 10.381807982178714, 93.17067618435921, 77.14267131091658, 15.403590969961432, 10.521920619563687, 6.392604817925348, 22.368706830369113, 29.27000335658942, -3.9729707442453086, -11.499164336992294, 6.480075912347711, 16.82322620509109, -12.056660158677257, -4.11234469966655, -15.680382999629494, -9.269181050252447, 36.19442202201411, 2.577605160552994, 17.862802601182583, 3.4138488930804374, 29.127242614051447, 32.45657978636295, -16.098504865893215, 28.907157201045774, -10.38417269362237, 24.983181047929538, -8.572311273146244, 7.235343376775423, -15.819756955050735, 1.1838656063405892, 20.96451422950012, -8.154189406882523, -6.3423279864063975], 'NLP Applications': [25.985744407203367, 41.1516185906427, 43.872522842129214, 24.823744032244065, 5.094228872313989, 15.705986685981616, 6.865395045730898, 2.372916411648367, 7.070990200155333, 39.34942944479165, 20.22908008331918, 19.3811191109128, 6.318819402515344, 2.1367064939688976, 0.740128935248987, 6.454204736882027, 4.958163223581314, 1.5565227248474642, 1.6925882707825652], 'Summarization': [8.85195206803246, 64.28295322767686, 38.925396211828364, 15.384615384615374, 10.398144568998834, 26.555856204097406, 53.382296095863936, 70.23579435639736, 39.19597989949749, 44.375724777734824, 17.510630073444137, 20.718979512949357, 17.89717819868573, 97.56474681097795, 63.6644762272903, 8.310784692694236, 46.57904909161191, 11.403169694626982, -5.682257441051408, 36.21955933513722, 33.784306146115185, -3.4789331271743364, 65.67452647854658, 30.76923076923076, 1.2369540007730888, 54.46463084654039, 11.016621569385388, 8.735987630459984, 43.21608040201005, 3.826826439891764, 56.93853884808659, 35.52377270970235, 14.882102821801308, 19.250096637031305, 4.213374565133356, 20.21646695013529, 0.115964437572465, -2.2033243138770926, 9.393119443370695, 16.814843448009274], 'Generation': [2.4614285280602504, 57.37353219331586, -33.66226988014683, 41.49952899021759, 79.88679242222314, 2.8740409765765094, 49.049890422152224, 20.23495775511524, 14.908288080474657, -33.757884286627004, -31.868291760492042, -1.52695554803176, -19.654838701454427, 6.669903598839172, 4.956663855671022, -36.08695640083175, 20.52178567977313, -35.37844019635719, 41.88616950744079, 28.319938579860903, -20.278725861183155, -20.415151382428192, 1.1309052634213412, 39.77811882053125, 96.13559682211495, 15.45917115719167, 20.366110515927776, 17.301658533781886, 26.969728380882728, 8.907982648300882, -5.406427099388513, -24.5184117897746, -39.0731313077943, 35.28547016509327, -37.5540395954113, -35.376225928966846, -13.396158970262537, 31.981006197399566, -17.106089015171257, 22.328316181161604, -5.265718343797508, -22.200069429043452, -39.46405737675475, -37.054672127367525, -17.59057419626496, 82.93775116176619, 69.08730980300551], 'Semantics: Sentence-level Semantics,Textual Inference,and Other Areas': [31.894231928077097, 27.4630602107987, 34.82149088207031, 36.191125844998204, 36.21798145888827, 32.8878887001837, 27.839038401619998, 24.240389773107864, 14.545522846145326, 27.919605108743685, 12.423931501574828, 35.197469072891614, 27.355637755238483, 33.962112179413985, 25.341468731681715, 25.368324345571757, 10.593857596197134, 15.91515780907323, 15.754024260279378, 18.09046038142384, 20.641741144595745, 9.416105840457938, 5.077451518611099, 5.3877677933443975, 3.193800662850013, 8.905849714732863, 2.9919809283041903, 9.584758923467975, 16.425413934798307, 6.961102374372184, -6.0091792324398545], 'Syntax:Tagging,Chunking and Parsing': [-1.7264716013224501, 26.17219139067125, 35.82820784108662, 91.12082570638724, 5.298388716484017, -0.8343428787546143, 40.00668795495027, 3.2019258909016046, 31.45822406209992, 18.92030578476227, 17.476369818678393, 9.1509406544759, 15.077763687984572, 58.43207556933 ...
# Question Answering 24.43573707501521
# NLP Applications 14.51367944815262
# Summarization 27.75415539234634
# Generation 6.6314246179308345
# Semantics: Sentence-level Semantics,Textual Inference,and Other Areas 19.24514749648626
# Syntax:Tagging,Chunking and Parsing 23.91746402958159
# Dialogue and Interactive Systems 37.674801512551106
